# %%
import torch
import torch.nn as nn
import torchvision
from torchvision import models
from torchvision import datasets
from torchvision import transforms
from torchmetrics.classification import MulticlassAccuracy
import numpy as np
from collections import OrderedDict
import matplotlib.pyplot as plt
import datetime
import pandas as pd

# %%
no_epochs = 50
learning_rate = 0.0001
batch_size = 128
num_classes = 102

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

acc_function = MulticlassAccuracy(num_classes=102, average='micro').to(device)
loss_fn = nn.CrossEntropyLoss()

SEED = 196
np.random.seed(SEED)
generator = torch.Generator().manual_seed(SEED)
# Out:
# cuda:0

# %%
# Data Augmentation
train_transforms = transforms.Compose([
    transforms.RandomRotation(30),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

default_transforms = transforms.Compose([
    models.VGG16_BN_Weights.IMAGENET1K_V1.transforms()
])

flowers_train = datasets.Flowers102(root='./data', split='train', download=True, transform=train_transforms)
flowers_test = datasets.Flowers102(root='./data', split='test', download=True, transform=default_transforms)
flowers_val = datasets.Flowers102(root='./data', split='val', download=True, transform=default_transforms)

# %%
def get_data_loader(batch_size):
    train_loader = torch.utils.data.DataLoader(flowers_train, batch_size=batch_size, shuffle=True, generator=generator)
    test_loader = torch.utils.data.DataLoader(flowers_test, batch_size=batch_size, shuffle=True, generator=generator)
    val_loader = torch.utils.data.DataLoader(flowers_val, batch_size=batch_size, shuffle=True, generator=generator)
    return train_loader, test_loader, val_loader

# %%
# Early stopping based on accuracy
class AccuracyEarlyStopper:
    def __init__(self, patience=5, min_delta=0.01):
        self.patience = patience
        self.min_delta = min_delta
        self.counter = 0
        self.max_validation_accuracy = 0

    def early_stop(self, validation_accuracy):
        if validation_accuracy > (self.max_validation_accuracy + self.min_delta):
            self.max_validation_accuracy = validation_accuracy
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                return True
        return False

# %%
def train(model, optimizer, dataloader, loss_fn=loss_fn):
    running_loss_value = 0
    for images, labels in dataloader:
        optimizer.zero_grad()
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        loss = loss_fn(outputs, labels)
        running_loss_value += loss.item()
        loss.backward()
        optimizer.step()
    return running_loss_value / len(dataloader)

def test_eval(model, dataloader, loss_fn=loss_fn):
    running_loss_value = 0
    running_acc_value = 0
    with torch.no_grad():
        for images, labels in dataloader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            loss = loss_fn(outputs, labels)
            acc = acc_function(outputs, labels)
            running_loss_value += loss.item()
            running_acc_value += acc.item()
    running_acc_value /= len(dataloader)
    running_loss_value /= len(dataloader)
    return running_acc_value*100, running_loss_value

def train_eval_test(model, train_dataloader, val_dataloader, test_dataloader, no_epochs=10):
    es = AccuracyEarlyStopper()
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    train_loss_arr, train_acc_arr, eval_loss_arr, eval_acc_arr, train_time = [], [], [], [], []
    for i in range(no_epochs):
        start = datetime.datetime.now()
        train_loss = train(model, optimizer, train_dataloader)
        end = datetime.datetime.now()
        eval_acc, eval_loss = test_eval(model, val_dataloader)
        time_taken = (end-start).total_seconds()
        print(f'Epoch {i+1} Train Loss: {train_loss:>8f}, Eval Accuracy: {eval_acc:>0.2f}%, Eval Loss: {eval_loss:>8f}, Train Time: {time_taken:>0.2f}s')
        train_loss_arr.append(train_loss)
        eval_loss_arr.append(eval_loss)
        eval_acc_arr.append(eval_acc)
        train_time.append(time_taken)
        if es.early_stop(eval_acc):
            print('Early stopping activated')
            break
    test_acc, test_loss = test_eval(model, test_dataloader)
    print(f"Test Accuracy: {test_acc:>0.2f}%, Test Loss: {test_loss:>8f}")
    return train_loss_arr, train_acc_arr, eval_loss_arr, eval_acc_arr, test_acc, test_loss, train_time

# %%
class ModifiedResNet(nn.Module):
    def __init__(self, num_classes=102):
        super(ModifiedResNet, self).__init__()
        self.resnet = models.resnet34(weights=models.ResNet34_Weights.DEFAULT)
                        
        new_last_layer_1 = nn.Sequential(OrderedDict([
            ('conv1', nn.Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), bias=False)),
            ('bn1', nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
            ('relu1', nn.ReLU(inplace=True)),
            ('conv2', nn.Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1,1), bias=False)),
            ('bn2', nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
            ('conv3', nn.Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)),
            ('bn3', nn.BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
            ('relu2', nn.ReLU(inplace=True)),
            ('downsample', nn.Sequential(OrderedDict([
                ('0', nn.Conv2d(2048, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)),
                ('1', nn.BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))
            ])))
        ]))
        
        new_last_layer_2 = nn.Sequential(OrderedDict([
            ('conv1', nn.Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)),
            ('bn1', nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
            ('conv2', nn.Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)),
            ('bn2', nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
            ('conv3', nn.Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)),
            ('bn3', nn.BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
            ('relu', nn.ReLU(inplace=True))
        ]))
        
        new_last_layer_3 = nn.Sequential(OrderedDict([
            ('conv1', nn.Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)),
            ('bn1', nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
            ('conv2', nn.Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)),
            ('bn2', nn.BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
            ('conv3', nn.Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)),
            ('bn3', nn.BatchNorm2d(2048, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
            ('relu', nn.ReLU(inplace=True))
        ]))
        
        new_last_layer = nn.Sequential(OrderedDict([
            ('1', new_last_layer_1),
            ('2', new_last_layer_2),
            ('3', new_last_layer_3)
        ]))
        self.resnet.layer4 = new_last_layer
        self.resnet.fc = nn.Linear(2048, num_classes, bias=True)
        
    def forward(self, x):
        return self.resnet(x)

# %%
train_data_loader, test_data_loader, val_data_loader = get_data_loader(batch_size)

# %%
class ResNet34WithSE(nn.Module):
    def __init__(self, num_classes):
        super(ResNet34WithSE, self).__init__()
        self.resnet = torchvision.models.resnet34(weights=models.ResNet34_Weights.DEFAULT)

        self.resnet.layer1.add_module('SEBlock', torchvision.ops.SqueezeExcitation(64, 16))
        self.resnet.layer4.add_module('SEBlock', torchvision.ops.SqueezeExcitation(512, 16))
        self.resnet.fc = nn.Linear(512, num_classes)

        
    def forward(self, x):
        x = self.resnet(x)
        return x


SE_model = ResNet34WithSE(num_classes)

SE_model = SE_model.to(device=device)

# %%
model_epochs = 5

# %%
base_eval_acc_arr, base_test_acc_arr, base_time_taken_arr = [], [], []
modified_eval_acc_arr, modified_test_acc_arr, modified_time_taken_arr = [], [], []
SE_eval_acc_arr, SE_test_acc_arr, SE_time_taken_arr = [], [], []

for i in range(model_epochs):
    
    base_model = models.resnet34(weights=models.ResNet34_Weights.DEFAULT)
    base_model.fc = nn.Linear(512, 102)
    base_model = base_model.to(device)
    base_train_acc, base_train_loss, base_eval_loss, base_eval_acc, base_test_acc, base_test_loss, base_train_time = train_eval_test(
        base_model, 
        train_data_loader, 
        val_data_loader, 
        test_data_loader,
        no_epochs=no_epochs
    )
        
    base_eval_acc_arr.append(np.mean(base_eval_acc))
    base_test_acc_arr.append(base_test_acc)
    base_time_taken_arr.append(np.mean(base_train_time))
    
    del base_model
    
    
    modified_model = ModifiedResNet().to(device)
    modified_train_acc, modified_train_loss, modified_eval_loss, modified_eval_acc, modified_test_acc, modified_test_loss, modified_train_time = train_eval_test(
        modified_model, 
        train_data_loader, 
        val_data_loader, 
        test_data_loader,
        no_epochs=no_epochs
    )

    modified_eval_acc_arr.append(np.mean(modified_eval_acc))
    modified_test_acc_arr.append(modified_test_acc)
    modified_time_taken_arr.append(np.mean(modified_train_time))
    
    del modified_model
    
    
    SE_model = ResNet34WithSE(num_classes)

    SE_model = SE_model.to(device=device)
    SE_train_acc, SE_train_loss, SE_eval_loss, SE_eval_acc, SE_test_acc, SE_test_loss, SE_train_time = train_eval_test(
        SE_model, 
        train_data_loader, 
        val_data_loader, 
        test_data_loader,
        no_epochs=no_epochs
    )

    del SE_model
    
    SE_eval_acc_arr.append(np.mean(SE_eval_acc))
    SE_test_acc_arr.append(SE_test_acc)
    SE_time_taken_arr.append(np.mean(SE_train_time))
# Out:
# Epoch 1 Train Loss: 4.592120, Eval Accuracy: 15.32%, Eval Loss: 3.996889, Train Time: 12.46s
# Epoch 2 Train Loss: 3.653284, Eval Accuracy: 47.15%, Eval Loss: 3.216567, Train Time: 9.30s
# Epoch 3 Train Loss: 2.834914, Eval Accuracy: 67.34%, Eval Loss: 2.569592, Train Time: 9.26s
# Epoch 4 Train Loss: 2.235977, Eval Accuracy: 75.87%, Eval Loss: 2.067852, Train Time: 9.40s
# Epoch 5 Train Loss: 1.774195, Eval Accuracy: 79.61%, Eval Loss: 1.682817, Train Time: 9.56s
# Epoch 6 Train Loss: 1.390882, Eval Accuracy: 83.55%, Eval Loss: 1.379688, Train Time: 9.52s
# Epoch 7 Train Loss: 1.125768, Eval Accuracy: 87.97%, Eval Loss: 1.135820, Train Time: 9.60s
# Epoch 8 Train Loss: 0.917505, Eval Accuracy: 87.16%, Eval Loss: 0.971901, Train Time: 9.37s
# Epoch 9 Train Loss: 0.733289, Eval Accuracy: 89.70%, Eval Loss: 0.835197, Train Time: 9.37s
# Epoch 10 Train Loss: 0.603535, Eval Accuracy: 90.30%, Eval Loss: 0.736045, Train Time: 9.22s
# Epoch 11 Train Loss: 0.506020, Eval Accuracy: 91.46%, Eval Loss: 0.656032, Train Time: 9.54s
# Epoch 12 Train Loss: 0.404337, Eval Accuracy: 91.48%, Eval Loss: 0.603944, Train Time: 9.40s
# Epoch 13 Train Loss: 0.385343, Eval Accuracy: 91.67%, Eval Loss: 0.556135, Train Time: 9.29s
# Epoch 14 Train Loss: 0.352509, Eval Accuracy: 93.13%, Eval Loss: 0.511150, Train Time: 9.26s
# Epoch 15 Train Loss: 0.295353, Eval Accuracy: 92.64%, Eval Loss: 0.476454, Train Time: 9.31s
# Epoch 16 Train Loss: 0.252942, Eval Accuracy: 92.74%, Eval Loss: 0.465101, Train Time: 9.25s
# Epoch 17 Train Loss: 0.260914, Eval Accuracy: 92.54%, Eval Loss: 0.473268, Train Time: 9.65s
# Epoch 18 Train Loss: 0.231385, Eval Accuracy: 92.94%, Eval Loss: 0.440364, Train Time: 9.13s
# Epoch 19 Train Loss: 0.178444, Eval Accuracy: 93.13%, Eval Loss: 0.422848, Train Time: 9.21s
# Early stopping activated
# Test Accuracy: 87.94%, Test Loss: 0.604932
# Epoch 1 Train Loss: 4.346682, Eval Accuracy: 32.45%, Eval Loss: 3.667329, Train Time: 10.33s
# Epoch 2 Train Loss: 3.474021, Eval Accuracy: 48.14%, Eval Loss: 2.974892, Train Time: 9.29s
# Epoch 3 Train Loss: 2.836143, Eval Accuracy: 57.93%, Eval Loss: 2.480184, Train Time: 9.27s
# Epoch 4 Train Loss: 2.387354, Eval Accuracy: 66.49%, Eval Loss: 2.073605, Train Time: 9.42s
# Epoch 5 Train Loss: 1.979926, Eval Accuracy: 73.62%, Eval Loss: 1.780822, Train Time: 9.49s
# Epoch 6 Train Loss: 1.633494, Eval Accuracy: 77.55%, Eval Loss: 1.515394, Train Time: 9.21s
# Epoch 7 Train Loss: 1.411708, Eval Accuracy: 82.26%, Eval Loss: 1.298127, Train Time: 9.50s
# Epoch 8 Train Loss: 1.197269, Eval Accuracy: 84.79%, Eval Loss: 1.150309, Train Time: 9.33s
# Epoch 9 Train Loss: 0.977042, Eval Accuracy: 83.71%, Eval Loss: 1.029720, Train Time: 9.36s
# Epoch 10 Train Loss: 0.807259, Eval Accuracy: 86.57%, Eval Loss: 0.908499, Train Time: 9.35s
# Epoch 11 Train Loss: 0.755255, Eval Accuracy: 86.16%, Eval Loss: 0.824761, Train Time: 9.32s
# Epoch 12 Train Loss: 0.628277, Eval Accuracy: 86.48%, Eval Loss: 0.761601, Train Time: 9.44s
# Epoch 13 Train Loss: 0.582041, Eval Accuracy: 87.16%, Eval Loss: 0.707923, Train Time: 9.39s
# Epoch 14 Train Loss: 0.496628, Eval Accuracy: 87.04%, Eval Loss: 0.661528, Train Time: 9.54s
# Epoch 15 Train Loss: 0.432212, Eval Accuracy: 87.76%, Eval Loss: 0.630996, Train Time: 9.30s
# Epoch 16 Train Loss: 0.377321, Eval Accuracy: 88.53%, Eval Loss: 0.614799, Train Time: 9.41s
# Epoch 17 Train Loss: 0.373414, Eval Accuracy: 87.27%, Eval Loss: 0.608292, Train Time: 9.38s
# Epoch 18 Train Loss: 0.364442, Eval Accuracy: 88.73%, Eval Loss: 0.560210, Train Time: 9.31s
# Epoch 19 Train Loss: 0.310081, Eval Accuracy: 88.82%, Eval Loss: 0.553471, Train Time: 9.40s
# Epoch 20 Train Loss: 0.304718, Eval Accuracy: 89.12%, Eval Loss: 0.531927, Train Time: 9.60s
# Epoch 21 Train Loss: 0.295603, Eval Accuracy: 89.52%, Eval Loss: 0.516815, Train Time: 9.33s
# Epoch 22 Train Loss: 0.292081, Eval Accuracy: 88.83%, Eval Loss: 0.532728, Train Time: 9.37s
# Epoch 23 Train Loss: 0.287174, Eval Accuracy: 88.63%, Eval Loss: 0.502992, Train Time: 9.40s
# Epoch 24 Train Loss: 0.261774, Eval Accuracy: 89.70%, Eval Loss: 0.477789, Train Time: 9.45s
# Epoch 25 Train Loss: 0.226556, Eval Accuracy: 89.13%, Eval Loss: 0.496361, Train Time: 9.29s
# Epoch 26 Train Loss: 0.226910, Eval Accuracy: 88.34%, Eval Loss: 0.498633, Train Time: 9.87s
# Epoch 27 Train Loss: 0.208830, Eval Accuracy: 89.12%, Eval Loss: 0.484421, Train Time: 9.47s
# Epoch 28 Train Loss: 0.240243, Eval Accuracy: 89.22%, Eval Loss: 0.466938, Train Time: 9.40s
# Epoch 29 Train Loss: 0.214002, Eval Accuracy: 88.93%, Eval Loss: 0.496735, Train Time: 9.30s
# Early stopping activated
# Test Accuracy: 83.84%, Test Loss: 0.673172
# Epoch 1 Train Loss: 4.531184, Eval Accuracy: 14.99%, Eval Loss: 4.211263, Train Time: 9.69s
# Epoch 2 Train Loss: 4.007278, Eval Accuracy: 41.14%, Eval Loss: 3.769640, Train Time: 9.09s
# Epoch 3 Train Loss: 3.547282, Eval Accuracy: 57.86%, Eval Loss: 3.349922, Train Time: 9.04s
# Epoch 4 Train Loss: 3.138866, Eval Accuracy: 65.78%, Eval Loss: 2.968689, Train Time: 9.05s
# Epoch 5 Train Loss: 2.753652, Eval Accuracy: 72.48%, Eval Loss: 2.604726, Train Time: 9.29s
# Epoch 6 Train Loss: 2.384147, Eval Accuracy: 76.47%, Eval Loss: 2.281639, Train Time: 9.48s
# Epoch 7 Train Loss: 2.072389, Eval Accuracy: 79.61%, Eval Loss: 1.984705, Train Time: 9.20s
# Epoch 8 Train Loss: 1.775977, Eval Accuracy: 81.87%, Eval Loss: 1.722857, Train Time: 9.51s
# Epoch 9 Train Loss: 1.490330, Eval Accuracy: 84.11%, Eval Loss: 1.494835, Train Time: 9.21s
# Epoch 10 Train Loss: 1.231886, Eval Accuracy: 86.67%, Eval Loss: 1.269710, Train Time: 8.97s
# Epoch 11 Train Loss: 1.027253, Eval Accuracy: 88.62%, Eval Loss: 1.081281, Train Time: 9.02s
# Epoch 12 Train Loss: 0.828480, Eval Accuracy: 88.73%, Eval Loss: 0.937195, Train Time: 9.16s
# Epoch 13 Train Loss: 0.665555, Eval Accuracy: 90.10%, Eval Loss: 0.831594, Train Time: 9.23s
# Epoch 14 Train Loss: 0.577472, Eval Accuracy: 91.28%, Eval Loss: 0.704615, Train Time: 9.04s
# Epoch 15 Train Loss: 0.466038, Eval Accuracy: 90.69%, Eval Loss: 0.640432, Train Time: 9.01s
# Epoch 16 Train Loss: 0.412417, Eval Accuracy: 91.48%, Eval Loss: 0.605494, Train Time: 9.13s
# Epoch 17 Train Loss: 0.339654, Eval Accuracy: 91.66%, Eval Loss: 0.571609, Train Time: 9.18s
# Epoch 18 Train Loss: 0.294415, Eval Accuracy: 90.67%, Eval Loss: 0.542220, Train Time: 8.98s
# Epoch 19 Train Loss: 0.250831, Eval Accuracy: 91.27%, Eval Loss: 0.493834, Train Time: 9.49s
# Epoch 20 Train Loss: 0.260817, Eval Accuracy: 90.98%, Eval Loss: 0.491998, Train Time: 9.13s
# Epoch 21 Train Loss: 0.210168, Eval Accuracy: 91.07%, Eval Loss: 0.487914, Train Time: 9.12s
# Epoch 22 Train Loss: 0.188749, Eval Accuracy: 91.77%, Eval Loss: 0.457261, Train Time: 9.06s
# Epoch 23 Train Loss: 0.204628, Eval Accuracy: 90.99%, Eval Loss: 0.463899, Train Time: 8.98s
# Epoch 24 Train Loss: 0.183781, Eval Accuracy: 91.28%, Eval Loss: 0.461587, Train Time: 9.19s
# Epoch 25 Train Loss: 0.205062, Eval Accuracy: 92.17%, Eval Loss: 0.431956, Train Time: 9.35s
# Epoch 26 Train Loss: 0.175051, Eval Accuracy: 91.17%, Eval Loss: 0.441878, Train Time: 9.06s
# Epoch 27 Train Loss: 0.171767, Eval Accuracy: 91.18%, Eval Loss: 0.449846, Train Time: 9.22s
# Epoch 28 Train Loss: 0.138506, Eval Accuracy: 91.19%, Eval Loss: 0.413970, Train Time: 9.15s
# Epoch 29 Train Loss: 0.132866, Eval Accuracy: 92.45%, Eval Loss: 0.399373, Train Time: 9.04s
# Epoch 30 Train Loss: 0.141028, Eval Accuracy: 91.19%, Eval Loss: 0.401839, Train Time: 9.08s
# Epoch 31 Train Loss: 0.126341, Eval Accuracy: 91.37%, Eval Loss: 0.406880, Train Time: 9.12s
# Epoch 32 Train Loss: 0.119152, Eval Accuracy: 92.27%, Eval Loss: 0.385386, Train Time: 9.96s
# Epoch 33 Train Loss: 0.115687, Eval Accuracy: 92.75%, Eval Loss: 0.365082, Train Time: 9.06s
# Epoch 34 Train Loss: 0.112501, Eval Accuracy: 92.45%, Eval Loss: 0.374562, Train Time: 8.99s
# Epoch 35 Train Loss: 0.129172, Eval Accuracy: 92.48%, Eval Loss: 0.362210, Train Time: 9.10s
# Epoch 36 Train Loss: 0.114264, Eval Accuracy: 92.45%, Eval Loss: 0.376457, Train Time: 9.06s
# Epoch 37 Train Loss: 0.096139, Eval Accuracy: 91.46%, Eval Loss: 0.404234, Train Time: 9.05s
# Epoch 38 Train Loss: 0.105905, Eval Accuracy: 93.06%, Eval Loss: 0.368302, Train Time: 9.25s
# Epoch 39 Train Loss: 0.106413, Eval Accuracy: 92.35%, Eval Loss: 0.347295, Train Time: 9.12s
# Epoch 40 Train Loss: 0.095249, Eval Accuracy: 92.73%, Eval Loss: 0.336851, Train Time: 9.14s
# Epoch 41 Train Loss: 0.106812, Eval Accuracy: 92.85%, Eval Loss: 0.355619, Train Time: 9.10s
# Epoch 42 Train Loss: 0.089088, Eval Accuracy: 91.38%, Eval Loss: 0.392784, Train Time: 9.11s
# Epoch 43 Train Loss: 0.074177, Eval Accuracy: 91.38%, Eval Loss: 0.398230, Train Time: 9.13s
# Early stopping activated
# Test Accuracy: 87.88%, Test Loss: 0.508691
# Epoch 1 Train Loss: 4.593075, Eval Accuracy: 17.84%, Eval Loss: 4.008878, Train Time: 9.55s
# Epoch 2 Train Loss: 3.645241, Eval Accuracy: 42.35%, Eval Loss: 3.252288, Train Time: 9.01s
# Epoch 3 Train Loss: 2.891141, Eval Accuracy: 61.55%, Eval Loss: 2.640030, Train Time: 9.05s
# Epoch 4 Train Loss: 2.315063, Eval Accuracy: 72.93%, Eval Loss: 2.144810, Train Time: 9.07s
# Epoch 5 Train Loss: 1.861109, Eval Accuracy: 78.83%, Eval Loss: 1.753180, Train Time: 9.33s
# Epoch 6 Train Loss: 1.445643, Eval Accuracy: 83.82%, Eval Loss: 1.427680, Train Time: 9.01s
# Epoch 7 Train Loss: 1.128269, Eval Accuracy: 85.30%, Eval Loss: 1.195640, Train Time: 9.03s
# Epoch 8 Train Loss: 0.911788, Eval Accuracy: 86.67%, Eval Loss: 1.025798, Train Time: 9.06s
# Epoch 9 Train Loss: 0.728474, Eval Accuracy: 88.72%, Eval Loss: 0.877393, Train Time: 9.65s
# Epoch 10 Train Loss: 0.608562, Eval Accuracy: 89.41%, Eval Loss: 0.757893, Train Time: 9.00s
# Epoch 11 Train Loss: 0.523091, Eval Accuracy: 90.39%, Eval Loss: 0.676860, Train Time: 9.49s
# Epoch 12 Train Loss: 0.455661, Eval Accuracy: 90.69%, Eval Loss: 0.624843, Train Time: 9.13s
# Epoch 13 Train Loss: 0.373258, Eval Accuracy: 90.09%, Eval Loss: 0.579383, Train Time: 9.18s
# Epoch 14 Train Loss: 0.346926, Eval Accuracy: 90.99%, Eval Loss: 0.544287, Train Time: 9.03s
# Epoch 15 Train Loss: 0.277664, Eval Accuracy: 91.77%, Eval Loss: 0.518802, Train Time: 9.04s
# Epoch 16 Train Loss: 0.283635, Eval Accuracy: 91.56%, Eval Loss: 0.495180, Train Time: 9.08s
# Epoch 17 Train Loss: 0.256918, Eval Accuracy: 91.66%, Eval Loss: 0.473476, Train Time: 9.89s
# Epoch 18 Train Loss: 0.228828, Eval Accuracy: 91.96%, Eval Loss: 0.455913, Train Time: 9.04s
# Epoch 19 Train Loss: 0.220135, Eval Accuracy: 92.84%, Eval Loss: 0.432320, Train Time: 9.04s
# Epoch 20 Train Loss: 0.170576, Eval Accuracy: 92.56%, Eval Loss: 0.421173, Train Time: 9.14s
# Epoch 21 Train Loss: 0.201899, Eval Accuracy: 92.36%, Eval Loss: 0.416865, Train Time: 9.14s
# Epoch 22 Train Loss: 0.178372, Eval Accuracy: 92.17%, Eval Loss: 0.414738, Train Time: 9.07s
# Epoch 23 Train Loss: 0.165822, Eval Accuracy: 91.95%, Eval Loss: 0.401458, Train Time: 9.26s
# Epoch 24 Train Loss: 0.141440, Eval Accuracy: 92.25%, Eval Loss: 0.393981, Train Time: 9.42s
# Early stopping activated
# Test Accuracy: 87.66%, Test Loss: 0.592999
# Epoch 1 Train Loss: 4.403602, Eval Accuracy: 30.69%, Eval Loss: 3.736319, Train Time: 9.75s
# Epoch 2 Train Loss: 3.522034, Eval Accuracy: 49.53%, Eval Loss: 2.987507, Train Time: 9.37s
# Epoch 3 Train Loss: 2.850737, Eval Accuracy: 60.60%, Eval Loss: 2.444167, Train Time: 9.61s
# Epoch 4 Train Loss: 2.348319, Eval Accuracy: 67.66%, Eval Loss: 2.052622, Train Time: 9.39s
# Epoch 5 Train Loss: 1.991377, Eval Accuracy: 73.93%, Eval Loss: 1.735502, Train Time: 9.46s
# Epoch 6 Train Loss: 1.654853, Eval Accuracy: 78.33%, Eval Loss: 1.481898, Train Time: 9.29s
# Epoch 7 Train Loss: 1.386370, Eval Accuracy: 81.37%, Eval Loss: 1.276027, Train Time: 9.30s
# Epoch 8 Train Loss: 1.192381, Eval Accuracy: 84.09%, Eval Loss: 1.129706, Train Time: 9.41s
# Epoch 9 Train Loss: 0.988955, Eval Accuracy: 85.11%, Eval Loss: 0.996951, Train Time: 10.27s
# Epoch 10 Train Loss: 0.863526, Eval Accuracy: 85.18%, Eval Loss: 0.897834, Train Time: 9.28s
# Epoch 11 Train Loss: 0.757333, Eval Accuracy: 86.87%, Eval Loss: 0.806728, Train Time: 9.31s
# Epoch 12 Train Loss: 0.667044, Eval Accuracy: 88.25%, Eval Loss: 0.734633, Train Time: 9.41s
# Epoch 13 Train Loss: 0.552622, Eval Accuracy: 88.73%, Eval Loss: 0.691594, Train Time: 9.33s
# Epoch 14 Train Loss: 0.514199, Eval Accuracy: 88.35%, Eval Loss: 0.664406, Train Time: 9.28s
# Epoch 15 Train Loss: 0.453780, Eval Accuracy: 88.53%, Eval Loss: 0.643216, Train Time: 9.65s
# Epoch 16 Train Loss: 0.408270, Eval Accuracy: 88.60%, Eval Loss: 0.596824, Train Time: 9.43s
# Epoch 17 Train Loss: 0.377258, Eval Accuracy: 89.50%, Eval Loss: 0.566966, Train Time: 9.36s
# Epoch 18 Train Loss: 0.353209, Eval Accuracy: 90.19%, Eval Loss: 0.543511, Train Time: 9.31s
# Epoch 19 Train Loss: 0.342266, Eval Accuracy: 89.12%, Eval Loss: 0.547087, Train Time: 9.33s
# Epoch 20 Train Loss: 0.297499, Eval Accuracy: 89.51%, Eval Loss: 0.508951, Train Time: 9.41s
# Epoch 21 Train Loss: 0.301308, Eval Accuracy: 89.02%, Eval Loss: 0.537345, Train Time: 9.31s
# Epoch 22 Train Loss: 0.290169, Eval Accuracy: 89.41%, Eval Loss: 0.516901, Train Time: 9.35s
# Epoch 23 Train Loss: 0.279628, Eval Accuracy: 87.76%, Eval Loss: 0.567936, Train Time: 9.36s
# Early stopping activated
# Test Accuracy: 83.93%, Test Loss: 0.736406
# Epoch 1 Train Loss: 4.523056, Eval Accuracy: 17.75%, Eval Loss: 4.210259, Train Time: 9.80s
# Epoch 2 Train Loss: 4.005162, Eval Accuracy: 43.01%, Eval Loss: 3.755626, Train Time: 9.05s
# Epoch 3 Train Loss: 3.535482, Eval Accuracy: 58.01%, Eval Loss: 3.349163, Train Time: 9.01s
# Epoch 4 Train Loss: 3.143424, Eval Accuracy: 67.14%, Eval Loss: 2.974772, Train Time: 9.09s
# Epoch 5 Train Loss: 2.760297, Eval Accuracy: 71.56%, Eval Loss: 2.624095, Train Time: 9.26s
# Epoch 6 Train Loss: 2.395413, Eval Accuracy: 75.59%, Eval Loss: 2.293667, Train Time: 9.07s
# Epoch 7 Train Loss: 2.085428, Eval Accuracy: 79.31%, Eval Loss: 1.992197, Train Time: 9.00s
# Epoch 8 Train Loss: 1.756313, Eval Accuracy: 81.46%, Eval Loss: 1.706499, Train Time: 9.17s
# Epoch 9 Train Loss: 1.474038, Eval Accuracy: 85.29%, Eval Loss: 1.452268, Train Time: 9.87s
# Epoch 10 Train Loss: 1.224475, Eval Accuracy: 86.54%, Eval Loss: 1.237692, Train Time: 9.09s
# Epoch 11 Train Loss: 1.010652, Eval Accuracy: 87.84%, Eval Loss: 1.060483, Train Time: 9.03s
# Epoch 12 Train Loss: 0.837366, Eval Accuracy: 89.31%, Eval Loss: 0.914814, Train Time: 9.17s
# Epoch 13 Train Loss: 0.646609, Eval Accuracy: 90.00%, Eval Loss: 0.805424, Train Time: 9.50s
# Epoch 14 Train Loss: 0.544284, Eval Accuracy: 90.50%, Eval Loss: 0.712486, Train Time: 9.32s
# Epoch 15 Train Loss: 0.449544, Eval Accuracy: 90.31%, Eval Loss: 0.655985, Train Time: 9.06s
# Epoch 16 Train Loss: 0.368660, Eval Accuracy: 90.90%, Eval Loss: 0.597650, Train Time: 9.16s
# Epoch 17 Train Loss: 0.313586, Eval Accuracy: 92.46%, Eval Loss: 0.537514, Train Time: 9.23s
# Epoch 18 Train Loss: 0.319284, Eval Accuracy: 92.73%, Eval Loss: 0.500838, Train Time: 9.61s
# Epoch 19 Train Loss: 0.279133, Eval Accuracy: 91.47%, Eval Loss: 0.491650, Train Time: 9.04s
# Epoch 20 Train Loss: 0.233716, Eval Accuracy: 92.25%, Eval Loss: 0.479570, Train Time: 9.41s
# Epoch 21 Train Loss: 0.191213, Eval Accuracy: 92.44%, Eval Loss: 0.455577, Train Time: 9.13s
# Epoch 22 Train Loss: 0.211878, Eval Accuracy: 91.85%, Eval Loss: 0.447487, Train Time: 9.02s
# Epoch 23 Train Loss: 0.167557, Eval Accuracy: 92.36%, Eval Loss: 0.418616, Train Time: 9.09s
# Early stopping activated
# Test Accuracy: 88.84%, Test Loss: 0.572073
# Epoch 1 Train Loss: 4.532418, Eval Accuracy: 19.22%, Eval Loss: 3.908964, Train Time: 9.58s
# Epoch 2 Train Loss: 3.564558, Eval Accuracy: 48.52%, Eval Loss: 3.121766, Train Time: 9.01s
# Epoch 3 Train Loss: 2.809467, Eval Accuracy: 68.35%, Eval Loss: 2.502898, Train Time: 9.08s
# Epoch 4 Train Loss: 2.239272, Eval Accuracy: 75.56%, Eval Loss: 2.035487, Train Time: 9.11s
# Epoch 5 Train Loss: 1.768095, Eval Accuracy: 80.21%, Eval Loss: 1.663268, Train Time: 9.51s
# Epoch 6 Train Loss: 1.375888, Eval Accuracy: 84.99%, Eval Loss: 1.354462, Train Time: 9.26s
# Epoch 7 Train Loss: 1.139969, Eval Accuracy: 86.38%, Eval Loss: 1.121262, Train Time: 9.33s
# Epoch 8 Train Loss: 0.870265, Eval Accuracy: 88.05%, Eval Loss: 0.946200, Train Time: 9.16s
# Epoch 9 Train Loss: 0.733761, Eval Accuracy: 89.20%, Eval Loss: 0.820853, Train Time: 9.19s
# Epoch 10 Train Loss: 0.571084, Eval Accuracy: 90.90%, Eval Loss: 0.721474, Train Time: 9.71s
# Epoch 11 Train Loss: 0.458296, Eval Accuracy: 90.40%, Eval Loss: 0.658120, Train Time: 9.08s
# Epoch 12 Train Loss: 0.413987, Eval Accuracy: 90.69%, Eval Loss: 0.605326, Train Time: 9.18s
# Epoch 13 Train Loss: 0.369926, Eval Accuracy: 91.37%, Eval Loss: 0.552989, Train Time: 9.66s
# Epoch 14 Train Loss: 0.343504, Eval Accuracy: 91.07%, Eval Loss: 0.519891, Train Time: 9.04s
# Epoch 15 Train Loss: 0.268330, Eval Accuracy: 91.29%, Eval Loss: 0.498552, Train Time: 9.57s
# Epoch 16 Train Loss: 0.273682, Eval Accuracy: 91.18%, Eval Loss: 0.485758, Train Time: 9.19s
# Epoch 17 Train Loss: 0.237297, Eval Accuracy: 92.16%, Eval Loss: 0.449252, Train Time: 9.11s
# Epoch 18 Train Loss: 0.221903, Eval Accuracy: 91.20%, Eval Loss: 0.445610, Train Time: 9.06s
# Epoch 19 Train Loss: 0.201526, Eval Accuracy: 91.57%, Eval Loss: 0.425780, Train Time: 9.32s
# Epoch 20 Train Loss: 0.209243, Eval Accuracy: 91.39%, Eval Loss: 0.430369, Train Time: 9.37s
# Epoch 21 Train Loss: 0.196268, Eval Accuracy: 91.57%, Eval Loss: 0.428032, Train Time: 9.37s
# Epoch 22 Train Loss: 0.192683, Eval Accuracy: 91.76%, Eval Loss: 0.403115, Train Time: 9.23s
# Early stopping activated
# Test Accuracy: 88.97%, Test Loss: 0.552332
# Epoch 1 Train Loss: 4.358343, Eval Accuracy: 33.92%, Eval Loss: 3.691423, Train Time: 10.16s
# Epoch 2 Train Loss: 3.448224, Eval Accuracy: 51.87%, Eval Loss: 2.962940, Train Time: 9.59s
# Epoch 3 Train Loss: 2.823720, Eval Accuracy: 61.47%, Eval Loss: 2.437720, Train Time: 12.11s
# Epoch 4 Train Loss: 2.331440, Eval Accuracy: 67.55%, Eval Loss: 2.034559, Train Time: 9.46s
# Epoch 5 Train Loss: 1.908585, Eval Accuracy: 75.67%, Eval Loss: 1.726014, Train Time: 9.35s
# Epoch 6 Train Loss: 1.595580, Eval Accuracy: 79.22%, Eval Loss: 1.465766, Train Time: 9.37s
# Epoch 7 Train Loss: 1.360618, Eval Accuracy: 83.82%, Eval Loss: 1.277315, Train Time: 9.42s
# Epoch 8 Train Loss: 1.136545, Eval Accuracy: 85.00%, Eval Loss: 1.108452, Train Time: 9.45s
# Epoch 9 Train Loss: 0.956128, Eval Accuracy: 84.78%, Eval Loss: 0.986514, Train Time: 9.30s
# Epoch 10 Train Loss: 0.818257, Eval Accuracy: 86.20%, Eval Loss: 0.892558, Train Time: 9.27s
# Epoch 11 Train Loss: 0.730593, Eval Accuracy: 87.36%, Eval Loss: 0.816960, Train Time: 9.42s
# Epoch 12 Train Loss: 0.607649, Eval Accuracy: 88.15%, Eval Loss: 0.740405, Train Time: 10.05s
# Epoch 13 Train Loss: 0.523663, Eval Accuracy: 86.67%, Eval Loss: 0.718959, Train Time: 9.47s
# Epoch 14 Train Loss: 0.459641, Eval Accuracy: 89.21%, Eval Loss: 0.652602, Train Time: 9.33s
# Epoch 15 Train Loss: 0.485643, Eval Accuracy: 89.32%, Eval Loss: 0.638297, Train Time: 9.39s
# Epoch 16 Train Loss: 0.379842, Eval Accuracy: 88.23%, Eval Loss: 0.615183, Train Time: 9.72s
# Epoch 17 Train Loss: 0.332855, Eval Accuracy: 88.72%, Eval Loss: 0.590672, Train Time: 9.56s
# Epoch 18 Train Loss: 0.345547, Eval Accuracy: 88.83%, Eval Loss: 0.558294, Train Time: 9.61s
# Epoch 19 Train Loss: 0.286872, Eval Accuracy: 90.10%, Eval Loss: 0.529235, Train Time: 9.71s
# Epoch 20 Train Loss: 0.289067, Eval Accuracy: 88.06%, Eval Loss: 0.561875, Train Time: 9.67s
# Epoch 21 Train Loss: 0.285400, Eval Accuracy: 89.81%, Eval Loss: 0.509894, Train Time: 9.64s
# Epoch 22 Train Loss: 0.270208, Eval Accuracy: 88.05%, Eval Loss: 0.536369, Train Time: 9.53s
# Epoch 23 Train Loss: 0.276587, Eval Accuracy: 87.64%, Eval Loss: 0.543762, Train Time: 9.71s
# Epoch 24 Train Loss: 0.238886, Eval Accuracy: 89.51%, Eval Loss: 0.488217, Train Time: 9.68s
# Early stopping activated
# Test Accuracy: 84.48%, Test Loss: 0.683764
# Epoch 1 Train Loss: 4.556840, Eval Accuracy: 14.21%, Eval Loss: 4.269305, Train Time: 9.51s
# Epoch 2 Train Loss: 4.070127, Eval Accuracy: 38.53%, Eval Loss: 3.822495, Train Time: 9.04s
# Epoch 3 Train Loss: 3.601338, Eval Accuracy: 54.33%, Eval Loss: 3.409762, Train Time: 9.06s
# Epoch 4 Train Loss: 3.179709, Eval Accuracy: 64.45%, Eval Loss: 3.021232, Train Time: 9.21s
# Epoch 5 Train Loss: 2.785939, Eval Accuracy: 70.19%, Eval Loss: 2.656414, Train Time: 9.30s
# Epoch 6 Train Loss: 2.472671, Eval Accuracy: 73.42%, Eval Loss: 2.347935, Train Time: 9.04s
# Epoch 7 Train Loss: 2.101722, Eval Accuracy: 76.19%, Eval Loss: 2.036562, Train Time: 9.10s
# Epoch 8 Train Loss: 1.820131, Eval Accuracy: 80.28%, Eval Loss: 1.767980, Train Time: 9.17s
# Epoch 9 Train Loss: 1.573396, Eval Accuracy: 81.76%, Eval Loss: 1.548500, Train Time: 9.15s
# Epoch 10 Train Loss: 1.314027, Eval Accuracy: 83.80%, Eval Loss: 1.341285, Train Time: 9.50s
# Epoch 11 Train Loss: 1.077917, Eval Accuracy: 85.67%, Eval Loss: 1.143581, Train Time: 9.95s
# Epoch 12 Train Loss: 0.911272, Eval Accuracy: 88.53%, Eval Loss: 0.997627, Train Time: 9.20s
# Epoch 13 Train Loss: 0.735487, Eval Accuracy: 89.02%, Eval Loss: 0.872367, Train Time: 9.16s
# Epoch 14 Train Loss: 0.599147, Eval Accuracy: 90.58%, Eval Loss: 0.760672, Train Time: 9.07s
# Epoch 15 Train Loss: 0.497462, Eval Accuracy: 90.69%, Eval Loss: 0.693625, Train Time: 11.72s
# Epoch 16 Train Loss: 0.423820, Eval Accuracy: 91.18%, Eval Loss: 0.609906, Train Time: 9.71s
# Epoch 17 Train Loss: 0.378791, Eval Accuracy: 90.68%, Eval Loss: 0.569175, Train Time: 9.14s
# Epoch 18 Train Loss: 0.312376, Eval Accuracy: 91.56%, Eval Loss: 0.527840, Train Time: 9.05s
# Epoch 19 Train Loss: 0.302125, Eval Accuracy: 91.07%, Eval Loss: 0.524957, Train Time: 9.19s
# Epoch 20 Train Loss: 0.239589, Eval Accuracy: 92.06%, Eval Loss: 0.477509, Train Time: 8.83s
# Epoch 21 Train Loss: 0.252060, Eval Accuracy: 90.89%, Eval Loss: 0.458378, Train Time: 8.81s
# Epoch 22 Train Loss: 0.208072, Eval Accuracy: 91.69%, Eval Loss: 0.446541, Train Time: 9.16s
# Epoch 23 Train Loss: 0.214763, Eval Accuracy: 91.76%, Eval Loss: 0.450122, Train Time: 9.37s
# Epoch 24 Train Loss: 0.174163, Eval Accuracy: 91.86%, Eval Loss: 0.427980, Train Time: 9.43s
# Epoch 25 Train Loss: 0.184941, Eval Accuracy: 92.44%, Eval Loss: 0.405469, Train Time: 9.06s
# Epoch 26 Train Loss: 0.150909, Eval Accuracy: 91.77%, Eval Loss: 0.409949, Train Time: 11.58s
# Epoch 27 Train Loss: 0.145350, Eval Accuracy: 92.35%, Eval Loss: 0.385939, Train Time: 9.12s
# Epoch 28 Train Loss: 0.146258, Eval Accuracy: 92.65%, Eval Loss: 0.384163, Train Time: 9.11s
# Epoch 29 Train Loss: 0.129329, Eval Accuracy: 92.05%, Eval Loss: 0.385244, Train Time: 9.23s
# Epoch 30 Train Loss: 0.128887, Eval Accuracy: 92.05%, Eval Loss: 0.380041, Train Time: 9.23s
# Epoch 31 Train Loss: 0.150714, Eval Accuracy: 92.15%, Eval Loss: 0.384528, Train Time: 9.17s
# Epoch 32 Train Loss: 0.126474, Eval Accuracy: 91.27%, Eval Loss: 0.392859, Train Time: 9.48s
# Epoch 33 Train Loss: 0.150736, Eval Accuracy: 92.06%, Eval Loss: 0.393320, Train Time: 8.70s
# Early stopping activated
# Test Accuracy: 87.91%, Test Loss: 0.564636
# Epoch 1 Train Loss: 4.591042, Eval Accuracy: 17.26%, Eval Loss: 3.948751, Train Time: 9.32s
# Epoch 2 Train Loss: 3.598536, Eval Accuracy: 50.22%, Eval Loss: 3.166087, Train Time: 8.77s
# Epoch 3 Train Loss: 2.869483, Eval Accuracy: 64.51%, Eval Loss: 2.568012, Train Time: 9.51s
# Epoch 4 Train Loss: 2.277752, Eval Accuracy: 72.84%, Eval Loss: 2.086967, Train Time: 8.77s
# Epoch 5 Train Loss: 1.843976, Eval Accuracy: 77.33%, Eval Loss: 1.710066, Train Time: 9.52s
# Epoch 6 Train Loss: 1.483811, Eval Accuracy: 82.26%, Eval Loss: 1.414508, Train Time: 8.72s
# Epoch 7 Train Loss: 1.153395, Eval Accuracy: 85.20%, Eval Loss: 1.176851, Train Time: 8.70s
# Epoch 8 Train Loss: 0.880852, Eval Accuracy: 86.46%, Eval Loss: 1.002159, Train Time: 8.76s
# Epoch 9 Train Loss: 0.729059, Eval Accuracy: 89.31%, Eval Loss: 0.850132, Train Time: 8.94s
# Epoch 10 Train Loss: 0.653970, Eval Accuracy: 89.80%, Eval Loss: 0.752635, Train Time: 8.72s
# Epoch 11 Train Loss: 0.503008, Eval Accuracy: 90.20%, Eval Loss: 0.676788, Train Time: 8.73s
# Epoch 12 Train Loss: 0.450418, Eval Accuracy: 91.39%, Eval Loss: 0.615994, Train Time: 9.09s
# Epoch 13 Train Loss: 0.382010, Eval Accuracy: 90.80%, Eval Loss: 0.582178, Train Time: 8.91s
# Epoch 14 Train Loss: 0.299773, Eval Accuracy: 91.47%, Eval Loss: 0.541004, Train Time: 8.73s
# Epoch 15 Train Loss: 0.297972, Eval Accuracy: 91.84%, Eval Loss: 0.505149, Train Time: 8.75s
# Epoch 16 Train Loss: 0.252659, Eval Accuracy: 91.96%, Eval Loss: 0.477498, Train Time: 8.82s
# Epoch 17 Train Loss: 0.251313, Eval Accuracy: 92.45%, Eval Loss: 0.470154, Train Time: 8.84s
# Epoch 18 Train Loss: 0.238639, Eval Accuracy: 92.54%, Eval Loss: 0.457697, Train Time: 8.85s
# Epoch 19 Train Loss: 0.210494, Eval Accuracy: 93.04%, Eval Loss: 0.443047, Train Time: 9.14s
# Epoch 20 Train Loss: 0.178782, Eval Accuracy: 92.44%, Eval Loss: 0.421112, Train Time: 8.86s
# Epoch 21 Train Loss: 0.194349, Eval Accuracy: 93.43%, Eval Loss: 0.401182, Train Time: 8.91s
# Epoch 22 Train Loss: 0.176260, Eval Accuracy: 92.73%, Eval Loss: 0.409261, Train Time: 8.76s
# Epoch 23 Train Loss: 0.158385, Eval Accuracy: 92.65%, Eval Loss: 0.409750, Train Time: 8.75s
# Epoch 24 Train Loss: 0.140533, Eval Accuracy: 92.64%, Eval Loss: 0.394607, Train Time: 8.83s
# Epoch 25 Train Loss: 0.154071, Eval Accuracy: 93.05%, Eval Loss: 0.378247, Train Time: 9.45s
# Epoch 26 Train Loss: 0.123997, Eval Accuracy: 92.36%, Eval Loss: 0.373874, Train Time: 8.76s
# Early stopping activated
# Test Accuracy: 89.05%, Test Loss: 0.527842
# Epoch 1 Train Loss: 4.370748, Eval Accuracy: 34.80%, Eval Loss: 3.679555, Train Time: 10.15s
# Epoch 2 Train Loss: 3.441873, Eval Accuracy: 46.07%, Eval Loss: 2.988596, Train Time: 9.56s
# Epoch 3 Train Loss: 2.812223, Eval Accuracy: 59.72%, Eval Loss: 2.479324, Train Time: 9.00s
# Epoch 4 Train Loss: 2.332249, Eval Accuracy: 68.88%, Eval Loss: 2.066004, Train Time: 9.14s
# Epoch 5 Train Loss: 1.946655, Eval Accuracy: 72.70%, Eval Loss: 1.742023, Train Time: 9.28s
# Epoch 6 Train Loss: 1.599210, Eval Accuracy: 78.53%, Eval Loss: 1.496104, Train Time: 9.52s
# Epoch 7 Train Loss: 1.313235, Eval Accuracy: 80.71%, Eval Loss: 1.303509, Train Time: 9.09s
# Epoch 8 Train Loss: 1.134300, Eval Accuracy: 82.84%, Eval Loss: 1.127959, Train Time: 9.15s
# Epoch 9 Train Loss: 0.963788, Eval Accuracy: 83.21%, Eval Loss: 0.998902, Train Time: 9.19s
# Epoch 10 Train Loss: 0.814630, Eval Accuracy: 84.11%, Eval Loss: 0.916082, Train Time: 8.98s
# Epoch 11 Train Loss: 0.762217, Eval Accuracy: 86.36%, Eval Loss: 0.827059, Train Time: 9.02s
# Epoch 12 Train Loss: 0.620407, Eval Accuracy: 86.67%, Eval Loss: 0.751236, Train Time: 9.14s
# Epoch 13 Train Loss: 0.567570, Eval Accuracy: 86.77%, Eval Loss: 0.724880, Train Time: 9.11s
# Epoch 14 Train Loss: 0.510576, Eval Accuracy: 86.47%, Eval Loss: 0.697094, Train Time: 8.99s
# Epoch 15 Train Loss: 0.484388, Eval Accuracy: 86.47%, Eval Loss: 0.673858, Train Time: 9.49s
# Epoch 16 Train Loss: 0.431720, Eval Accuracy: 85.40%, Eval Loss: 0.653600, Train Time: 9.17s
# Epoch 17 Train Loss: 0.413542, Eval Accuracy: 86.29%, Eval Loss: 0.636961, Train Time: 9.05s
# Epoch 18 Train Loss: 0.372494, Eval Accuracy: 87.55%, Eval Loss: 0.586766, Train Time: 9.00s
# Epoch 19 Train Loss: 0.311136, Eval Accuracy: 87.28%, Eval Loss: 0.596856, Train Time: 9.17s
# Epoch 20 Train Loss: 0.280029, Eval Accuracy: 88.22%, Eval Loss: 0.548036, Train Time: 9.15s
# Epoch 21 Train Loss: 0.281805, Eval Accuracy: 88.23%, Eval Loss: 0.564333, Train Time: 9.45s
# Epoch 22 Train Loss: 0.264116, Eval Accuracy: 87.85%, Eval Loss: 0.557049, Train Time: 9.81s
# Epoch 23 Train Loss: 0.298470, Eval Accuracy: 87.46%, Eval Loss: 0.562867, Train Time: 9.05s
# Epoch 24 Train Loss: 0.249801, Eval Accuracy: 87.25%, Eval Loss: 0.556713, Train Time: 10.12s
# Epoch 25 Train Loss: 0.250945, Eval Accuracy: 87.86%, Eval Loss: 0.523056, Train Time: 9.15s
# Early stopping activated
# Test Accuracy: 83.89%, Test Loss: 0.691720
# Epoch 1 Train Loss: 4.552921, Eval Accuracy: 14.70%, Eval Loss: 4.247355, Train Time: 9.19s
# Epoch 2 Train Loss: 4.039348, Eval Accuracy: 38.60%, Eval Loss: 3.793287, Train Time: 8.72s
# Epoch 3 Train Loss: 3.573131, Eval Accuracy: 55.82%, Eval Loss: 3.375182, Train Time: 8.71s
# Epoch 4 Train Loss: 3.178298, Eval Accuracy: 64.06%, Eval Loss: 2.984082, Train Time: 8.96s
# Epoch 5 Train Loss: 2.783192, Eval Accuracy: 69.13%, Eval Loss: 2.636616, Train Time: 9.08s
# Epoch 6 Train Loss: 2.432384, Eval Accuracy: 74.41%, Eval Loss: 2.307025, Train Time: 9.49s
# Epoch 7 Train Loss: 2.108930, Eval Accuracy: 77.64%, Eval Loss: 2.016189, Train Time: 9.05s
# Epoch 8 Train Loss: 1.790161, Eval Accuracy: 80.38%, Eval Loss: 1.740468, Train Time: 9.08s
# Epoch 9 Train Loss: 1.501061, Eval Accuracy: 83.43%, Eval Loss: 1.500610, Train Time: 9.28s
# Epoch 10 Train Loss: 1.200447, Eval Accuracy: 85.69%, Eval Loss: 1.263879, Train Time: 9.61s
# Epoch 11 Train Loss: 1.026082, Eval Accuracy: 87.55%, Eval Loss: 1.106707, Train Time: 9.06s
# Epoch 12 Train Loss: 0.844085, Eval Accuracy: 88.83%, Eval Loss: 0.936133, Train Time: 9.61s
# Epoch 13 Train Loss: 0.673535, Eval Accuracy: 89.01%, Eval Loss: 0.826242, Train Time: 9.16s
# Epoch 14 Train Loss: 0.553758, Eval Accuracy: 89.80%, Eval Loss: 0.758266, Train Time: 9.07s
# Epoch 15 Train Loss: 0.472221, Eval Accuracy: 90.31%, Eval Loss: 0.668303, Train Time: 9.12s
# Epoch 16 Train Loss: 0.422359, Eval Accuracy: 90.08%, Eval Loss: 0.622240, Train Time: 9.16s
# Epoch 17 Train Loss: 0.376675, Eval Accuracy: 92.06%, Eval Loss: 0.570445, Train Time: 9.25s
# Epoch 18 Train Loss: 0.285680, Eval Accuracy: 91.66%, Eval Loss: 0.531609, Train Time: 9.09s
# Epoch 19 Train Loss: 0.301032, Eval Accuracy: 91.48%, Eval Loss: 0.501839, Train Time: 9.18s
# Epoch 20 Train Loss: 0.225731, Eval Accuracy: 91.27%, Eval Loss: 0.482595, Train Time: 9.35s
# Epoch 21 Train Loss: 0.237082, Eval Accuracy: 90.48%, Eval Loss: 0.476140, Train Time: 9.23s
# Epoch 22 Train Loss: 0.190817, Eval Accuracy: 90.78%, Eval Loss: 0.465751, Train Time: 9.03s
# Early stopping activated
# Test Accuracy: 87.19%, Test Loss: 0.632208
# Epoch 1 Train Loss: 4.529843, Eval Accuracy: 22.92%, Eval Loss: 3.934688, Train Time: 10.18s
# Epoch 2 Train Loss: 3.575315, Eval Accuracy: 47.94%, Eval Loss: 3.165749, Train Time: 9.92s
# Epoch 3 Train Loss: 2.853755, Eval Accuracy: 64.13%, Eval Loss: 2.558440, Train Time: 9.20s
# Epoch 4 Train Loss: 2.260710, Eval Accuracy: 73.35%, Eval Loss: 2.082098, Train Time: 9.45s
# Epoch 5 Train Loss: 1.813902, Eval Accuracy: 79.43%, Eval Loss: 1.703090, Train Time: 9.16s
# Epoch 6 Train Loss: 1.450896, Eval Accuracy: 82.65%, Eval Loss: 1.423851, Train Time: 9.61s
# Epoch 7 Train Loss: 1.155001, Eval Accuracy: 87.16%, Eval Loss: 1.169840, Train Time: 9.06s
# Epoch 8 Train Loss: 0.902441, Eval Accuracy: 88.62%, Eval Loss: 0.997673, Train Time: 9.11s
# Epoch 9 Train Loss: 0.741629, Eval Accuracy: 89.81%, Eval Loss: 0.861225, Train Time: 9.15s
# Epoch 10 Train Loss: 0.620499, Eval Accuracy: 89.50%, Eval Loss: 0.765116, Train Time: 9.06s
# Epoch 11 Train Loss: 0.568245, Eval Accuracy: 90.89%, Eval Loss: 0.682204, Train Time: 9.03s
# Epoch 12 Train Loss: 0.434887, Eval Accuracy: 90.78%, Eval Loss: 0.624404, Train Time: 9.68s
# Epoch 13 Train Loss: 0.362627, Eval Accuracy: 90.40%, Eval Loss: 0.592539, Train Time: 9.27s
# Epoch 14 Train Loss: 0.318905, Eval Accuracy: 91.27%, Eval Loss: 0.538994, Train Time: 9.12s
# Epoch 15 Train Loss: 0.311800, Eval Accuracy: 91.58%, Eval Loss: 0.516828, Train Time: 9.24s
# Epoch 16 Train Loss: 0.263098, Eval Accuracy: 91.28%, Eval Loss: 0.502365, Train Time: 9.68s
# Epoch 17 Train Loss: 0.242976, Eval Accuracy: 91.17%, Eval Loss: 0.475384, Train Time: 9.69s
# Epoch 18 Train Loss: 0.191731, Eval Accuracy: 91.38%, Eval Loss: 0.446410, Train Time: 9.26s
# Epoch 19 Train Loss: 0.220183, Eval Accuracy: 92.46%, Eval Loss: 0.418441, Train Time: 9.13s
# Epoch 20 Train Loss: 0.197181, Eval Accuracy: 92.25%, Eval Loss: 0.409297, Train Time: 12.68s
# Epoch 21 Train Loss: 0.177228, Eval Accuracy: 91.67%, Eval Loss: 0.430204, Train Time: 9.07s
# Epoch 22 Train Loss: 0.201052, Eval Accuracy: 91.35%, Eval Loss: 0.418338, Train Time: 9.05s
# Epoch 23 Train Loss: 0.139777, Eval Accuracy: 91.76%, Eval Loss: 0.399161, Train Time: 9.08s
# Epoch 24 Train Loss: 0.163720, Eval Accuracy: 91.37%, Eval Loss: 0.417556, Train Time: 9.33s
# Early stopping activated
# Test Accuracy: 87.84%, Test Loss: 0.562058
# Epoch 1 Train Loss: 4.373492, Eval Accuracy: 33.42%, Eval Loss: 3.670936, Train Time: 9.74s
# Epoch 2 Train Loss: 3.462550, Eval Accuracy: 48.44%, Eval Loss: 2.979986, Train Time: 10.01s
# Epoch 3 Train Loss: 2.834513, Eval Accuracy: 61.66%, Eval Loss: 2.464702, Train Time: 9.29s
# Epoch 4 Train Loss: 2.371555, Eval Accuracy: 69.05%, Eval Loss: 2.061523, Train Time: 9.71s
# Epoch 5 Train Loss: 1.965554, Eval Accuracy: 75.01%, Eval Loss: 1.743416, Train Time: 9.80s
# Epoch 6 Train Loss: 1.657432, Eval Accuracy: 78.42%, Eval Loss: 1.501563, Train Time: 9.74s
# Epoch 7 Train Loss: 1.353622, Eval Accuracy: 80.79%, Eval Loss: 1.311547, Train Time: 9.24s
# Epoch 8 Train Loss: 1.154125, Eval Accuracy: 84.02%, Eval Loss: 1.126528, Train Time: 9.58s
# Epoch 9 Train Loss: 0.978351, Eval Accuracy: 85.88%, Eval Loss: 0.989386, Train Time: 9.68s
# Epoch 10 Train Loss: 0.837441, Eval Accuracy: 86.86%, Eval Loss: 0.890156, Train Time: 9.52s
# Epoch 11 Train Loss: 0.689215, Eval Accuracy: 85.68%, Eval Loss: 0.830207, Train Time: 9.34s
# Epoch 12 Train Loss: 0.638597, Eval Accuracy: 87.36%, Eval Loss: 0.749644, Train Time: 9.43s
# Epoch 13 Train Loss: 0.545772, Eval Accuracy: 86.59%, Eval Loss: 0.721450, Train Time: 9.33s
# Epoch 14 Train Loss: 0.495088, Eval Accuracy: 87.73%, Eval Loss: 0.659016, Train Time: 9.31s
# Epoch 15 Train Loss: 0.477048, Eval Accuracy: 88.23%, Eval Loss: 0.633866, Train Time: 9.30s
# Epoch 16 Train Loss: 0.401777, Eval Accuracy: 89.31%, Eval Loss: 0.611336, Train Time: 9.90s
# Epoch 17 Train Loss: 0.362462, Eval Accuracy: 88.52%, Eval Loss: 0.579507, Train Time: 9.29s
# Epoch 18 Train Loss: 0.329461, Eval Accuracy: 87.26%, Eval Loss: 0.600753, Train Time: 9.32s
# Epoch 19 Train Loss: 0.318534, Eval Accuracy: 87.75%, Eval Loss: 0.585320, Train Time: 9.29s
# Epoch 20 Train Loss: 0.292733, Eval Accuracy: 89.42%, Eval Loss: 0.528942, Train Time: 9.76s
# Epoch 21 Train Loss: 0.271417, Eval Accuracy: 88.83%, Eval Loss: 0.537892, Train Time: 9.25s
# Epoch 22 Train Loss: 0.326225, Eval Accuracy: 88.05%, Eval Loss: 0.550721, Train Time: 9.82s
# Epoch 23 Train Loss: 0.266178, Eval Accuracy: 89.52%, Eval Loss: 0.516568, Train Time: 9.41s
# Epoch 24 Train Loss: 0.267293, Eval Accuracy: 88.13%, Eval Loss: 0.529207, Train Time: 9.33s
# Epoch 25 Train Loss: 0.233797, Eval Accuracy: 87.93%, Eval Loss: 0.549265, Train Time: 9.78s
# Epoch 26 Train Loss: 0.213419, Eval Accuracy: 89.71%, Eval Loss: 0.508571, Train Time: 9.35s
# Epoch 27 Train Loss: 0.217139, Eval Accuracy: 89.61%, Eval Loss: 0.491954, Train Time: 9.33s
# Epoch 28 Train Loss: 0.234192, Eval Accuracy: 90.10%, Eval Loss: 0.482603, Train Time: 9.61s
# Epoch 29 Train Loss: 0.203715, Eval Accuracy: 87.75%, Eval Loss: 0.530578, Train Time: 9.26s
# Epoch 30 Train Loss: 0.228564, Eval Accuracy: 89.21%, Eval Loss: 0.483841, Train Time: 9.33s
# Epoch 31 Train Loss: 0.206386, Eval Accuracy: 88.24%, Eval Loss: 0.490336, Train Time: 9.35s
# Epoch 32 Train Loss: 0.196449, Eval Accuracy: 89.53%, Eval Loss: 0.485478, Train Time: 9.32s
# Epoch 33 Train Loss: 0.171713, Eval Accuracy: 88.82%, Eval Loss: 0.485053, Train Time: 9.34s
# Early stopping activated
# Test Accuracy: 83.38%, Test Loss: 0.694380
# Epoch 1 Train Loss: 4.555998, Eval Accuracy: 11.37%, Eval Loss: 4.259211, Train Time: 9.56s
# Epoch 2 Train Loss: 4.055252, Eval Accuracy: 40.37%, Eval Loss: 3.817747, Train Time: 9.51s
# Epoch 3 Train Loss: 3.617561, Eval Accuracy: 57.08%, Eval Loss: 3.410877, Train Time: 9.07s
# Epoch 4 Train Loss: 3.192445, Eval Accuracy: 67.06%, Eval Loss: 3.034153, Train Time: 9.12s
# Epoch 5 Train Loss: 2.836433, Eval Accuracy: 72.04%, Eval Loss: 2.680204, Train Time: 9.22s
# Epoch 6 Train Loss: 2.461935, Eval Accuracy: 75.58%, Eval Loss: 2.351120, Train Time: 9.06s
# Epoch 7 Train Loss: 2.111912, Eval Accuracy: 78.82%, Eval Loss: 2.045216, Train Time: 9.02s
# Epoch 8 Train Loss: 1.832160, Eval Accuracy: 82.14%, Eval Loss: 1.762270, Train Time: 9.11s
# Epoch 9 Train Loss: 1.540071, Eval Accuracy: 83.83%, Eval Loss: 1.504633, Train Time: 9.20s
# Epoch 10 Train Loss: 1.239530, Eval Accuracy: 86.16%, Eval Loss: 1.287252, Train Time: 9.11s
# Epoch 11 Train Loss: 1.003887, Eval Accuracy: 88.92%, Eval Loss: 1.077084, Train Time: 9.62s
# Epoch 12 Train Loss: 0.862024, Eval Accuracy: 89.01%, Eval Loss: 0.949371, Train Time: 9.15s
# Epoch 13 Train Loss: 0.704746, Eval Accuracy: 90.48%, Eval Loss: 0.818947, Train Time: 9.18s
# Epoch 14 Train Loss: 0.565564, Eval Accuracy: 91.66%, Eval Loss: 0.706867, Train Time: 9.00s
# Epoch 15 Train Loss: 0.458696, Eval Accuracy: 91.18%, Eval Loss: 0.651882, Train Time: 9.19s
# Epoch 16 Train Loss: 0.385555, Eval Accuracy: 92.15%, Eval Loss: 0.588602, Train Time: 9.56s
# Epoch 17 Train Loss: 0.327491, Eval Accuracy: 91.19%, Eval Loss: 0.562363, Train Time: 9.83s
# Epoch 18 Train Loss: 0.298886, Eval Accuracy: 91.93%, Eval Loss: 0.526428, Train Time: 9.08s
# Epoch 19 Train Loss: 0.276911, Eval Accuracy: 91.86%, Eval Loss: 0.520653, Train Time: 9.05s
# Epoch 20 Train Loss: 0.244208, Eval Accuracy: 92.06%, Eval Loss: 0.501427, Train Time: 9.18s
# Epoch 21 Train Loss: 0.249350, Eval Accuracy: 92.45%, Eval Loss: 0.478598, Train Time: 9.08s
# Epoch 22 Train Loss: 0.178660, Eval Accuracy: 91.97%, Eval Loss: 0.456818, Train Time: 9.01s
# Epoch 23 Train Loss: 0.157778, Eval Accuracy: 91.28%, Eval Loss: 0.451628, Train Time: 9.12s
# Epoch 24 Train Loss: 0.181456, Eval Accuracy: 92.46%, Eval Loss: 0.419332, Train Time: 9.26s
# Epoch 25 Train Loss: 0.153903, Eval Accuracy: 92.05%, Eval Loss: 0.416115, Train Time: 9.10s
# Epoch 26 Train Loss: 0.193914, Eval Accuracy: 92.75%, Eval Loss: 0.404253, Train Time: 9.04s
# Epoch 27 Train Loss: 0.149528, Eval Accuracy: 92.53%, Eval Loss: 0.384366, Train Time: 9.05s
# Epoch 28 Train Loss: 0.137995, Eval Accuracy: 91.55%, Eval Loss: 0.407697, Train Time: 9.15s
# Epoch 29 Train Loss: 0.151806, Eval Accuracy: 90.99%, Eval Loss: 0.404007, Train Time: 9.09s
# Epoch 30 Train Loss: 0.131938, Eval Accuracy: 92.46%, Eval Loss: 0.366027, Train Time: 9.59s
# Epoch 31 Train Loss: 0.126623, Eval Accuracy: 92.64%, Eval Loss: 0.375616, Train Time: 9.59s
# Early stopping activated
# Test Accuracy: 88.52%, Test Loss: 0.529291

# %%
eval_acc = [np.mean(base_eval_acc_arr), np.mean(modified_eval_acc_arr), np.mean(SE_eval_acc_arr)]
test_acc = [np.mean(base_test_acc_arr), np.mean(modified_test_acc_arr), np.mean(SE_test_acc_arr)]
time_taken = [np.mean(base_time_taken_arr), np.mean(modified_time_taken_arr), np.mean(SE_time_taken_arr)]
names = ['base', 'modified', 'SE']
colours = ['tab:red', 'tab:blue', 'tab:green']

# %%
plt.figure(figsize=(18, 6))
plt.subplot(131)
plt.title('Validation Accuracies')
plt.scatter(names, eval_acc, color=colours)
plt.subplot(132)
plt.title('Test Accuracies')
plt.scatter(names, test_acc, color=colours)
plt.subplot(133)
plt.title('Training Times')
plt.scatter(names, time_taken, color=colours)
plt.show()

# %%
data = {'Names': names, 'Eval_Acc': eval_acc, 'Test_Acc': test_acc, 'Time_Taken': time_taken}

df = pd.DataFrame(data)
df
# Out:
#       Names   Eval_Acc   Test_Acc  Time_Taken
# 0      base  83.130376  88.293367    9.278725
# 1  modified  81.259389  83.903699    9.458951
# 2        SE  82.102201  88.069515    9.225316
